# %%
# !pip install langchain langchain-community langchain-groq sqlalchemy pyodbc python-dotenv pandas
# Out:
# Requirement already satisfied: langchain in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.3.2)
# Requirement already satisfied: langchain-community in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-groq in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.1.2)
# Requirement already satisfied: sqlalchemy in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.0.49)
# Requirement already satisfied: pyodbc in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (5.3.0)
# Requirement already satisfied: python-dotenv in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.2)
# Requirement already satisfied: pandas in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.2 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain) (1.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.3.45)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (4.1.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.2->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (3.11.9)
# Requirement already satisfied: requests<3,>=2 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.33.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.23.0)
# Requirement already satisfied: anyio in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.6.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: greenlet>=1 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ramya priya\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\ramya priya\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\ramya priya\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from langchain_groq import ChatGroq
from langchain_community.utilities import SQLDatabase
from langchain_classic.chains import create_sql_query_chain
from sqlalchemy import create_engine
from dotenv import load_dotenv
import pandas as pd
import os

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %%
GROQ_API_KEY="YOUR API KEY"

# %%
from langchain_groq import ChatGroq
import os

llm = ChatGroq(
    groq_api_key=os.getenv("GROQ_API_KEY"),
    model_name="llama-3.1-8b-instant",
    temperature=0
)

response = llm.invoke("Hello")
print(response.content)
# Out:
# Hello. How can I assist you today?

# %%
# SQL Server Configuration
SERVER = "RANI\RAMYASERVER"
DATABASE = "project_file"
USERNAME = "sa"
PASSWORD = "Password123"
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\R'
# <>:2: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\ramya priya\AppData\Local\Temp\ipykernel_24052\4102322620.py:2: SyntaxWarning: invalid escape sequence '\R'
#   SERVER = "RANI\RAMYASERVER"

# %%
# SQL Server Connection String
DATABASE_URI = (
    f"mssql+pyodbc://{USERNAME}:{PASSWORD}"
    f"@{SERVER}/{DATABASE}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

# %%
from sqlalchemy import create_engine

server = r"RANI\RAMYASERVER"
database = "project_file"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

engine = create_engine(connection_string)

# %%
# Create SQLAlchemy Engine
# 
#engine = create_engine(DATABASE_URI)

# %%
#engine = create_engine(
   # "mssql+pyodbc://@localhost\\SQLEXPRESS/master?"
    #"driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
#)

# %%
from sqlalchemy import create_engine

engine = create_engine(
    r"mssql+pyodbc://@RANI\RAMYASERVER/master"
    r"?driver=ODBC+Driver+17+for+SQL+Server"
    r"&trusted_connection=yes"
)

with engine.connect() as conn:
    print("Connected!")
# Out:
# Connected!

# %%
# Connect Database
db = SQLDatabase(engine)

# %%
# Show Available Tables
print("\nAvailable Tables:")
print(db.get_usable_table_names())
# Out:
# Available Tables:
# ['CHILD', 'CHILD1', 'DEPT', 'EMP', 'EMP1', 'EMP2', 'EMP3', 'EMP4', 'EMPLOYEES', 'MSreplication_options', 'PARENT', 'PARENT1', 'Prod', 'Products', 'Produs', 'SCHOOL1', 'SCHOOL2', 'spt_fallback_db', 'spt_fallback_dev', 'spt_fallback_usg', 'spt_monitor']

# %%
# Create SQL Query Chain
chain = create_sql_query_chain(llm, db)

# %%
# Function for asking questions
def ask_question(question):

    # Generate SQL Query
    sql_query = chain.invoke({
        "question": question
    })

    print("\nGenerated SQL Query:")
    print(sql_query)

    # Execute Query
    result = db.run(sql_query)

    return result

# %%
question = input("Ask your question: ")

# Get answer
response = llm.invoke(question)

# Print answer
print("\nAnswer:")
print(response.content)
# Out:
# Answer:
# **Maths Score SQL Query**
#
# Here's a simple SQL query to calculate the average maths score of a student:
#
# ```sql
# CREATE TABLE Students (
#   StudentID INT PRIMARY KEY,
#   Name VARCHAR(255),
#   MathsScore DECIMAL(5, 2)
# );
#
# INSERT INTO Students (StudentID, Name, MathsScore)
# VALUES
#   (1, 'John Doe', 85.50),
#   (2, 'Jane Doe', 92.25),
#   (3, 'Bob Smith', 78.00);
#
# SELECT
#   AVG(MathsScore) AS AverageMathsScore
# FROM
#   Students;
# ```
#
# **Result:**
#
# | AverageMathsScore |
# | --- |
# | 85.25 |
#
# This query creates a table called `Students` with columns for `StudentID`, `Name`, and `MathsScore`. It then inserts three sample students into the table. Finally, it selects the average `MathsScore` from the table using the `AVG` function.
#
# **Example Use Cases:**
#
# * Calculating the average score of a class
# * Finding the highest or lowest score in a class
# * Grouping scores by category (e.g., maths, science, English)
#
# **Tips and Variations:**
#
# * To calculate the average score for a specific student, use the `AVG` function with a `WHERE` clause: `SELECT AVG(MathsScore) FROM Students WHERE StudentID = 1;`
# * To calculate the average score for a specific category, use the `AVG` function with a `WHERE` clause: `SELECT AVG(MathsScore) FROM Students WHERE Category = 'Maths';`
# * To group scores by category, use the `GROUP BY` clause: `SELECT Category, AVG(MathsScore) FROM Students GROUP BY Category;`

# %%
question = input("Ask your question: ")

# Get answer
response = llm.invoke(question)

# Print answer
print("\nAnswer:")
print(response.content)
# Out:
# Answer:
# **Science Highest Score in SQL Format**
#
# To achieve the highest score in science, we need to create a SQL query that selects the student with the highest score in science from a given table.
#
# **Table Structure:**
#
# ```sql
# CREATE TABLE Students (
#   StudentID INT PRIMARY KEY,
#   Name VARCHAR(255),
#   ScienceScore INT,
#   MathScore INT,
#   EnglishScore INT
# );
# ```
#
# **Insert Sample Data:**
#
# ```sql
# INSERT INTO Students (StudentID, Name, ScienceScore, MathScore, EnglishScore)
# VALUES
#   (1, 'John Doe', 90, 80, 70),
#   (2, 'Jane Doe', 95, 85, 75),
#   (3, 'Bob Smith', 80, 90, 85),
#   (4, 'Alice Johnson', 85, 80, 90);
# ```
#
# **SQL Query:**
#
# ```sql
# SELECT Name, ScienceScore
# FROM Students
# ORDER BY ScienceScore DESC
# LIMIT 1;
# ```
#
# **Explanation:**
#
# 1. `SELECT Name, ScienceScore`: Select the `Name` and `ScienceScore` columns from the `Students` table.
# 2. `FROM Students`: Specify the `Students` table as the source of the data.
# 3. `ORDER BY ScienceScore DESC`: Sort the results in descending order based on the `ScienceScore` column. This will put the student with the highest score at the top.
# 4. `LIMIT 1`: Return only the top row, which corresponds to the student with the highest score in science.
#
# **Result:**
#
# | Name        | ScienceScore |
# |-------------|--------------|
# | Jane Doe    | 95           |
#
# This query will return the student with the highest score in science, which is Jane Doe with a score of 95.
